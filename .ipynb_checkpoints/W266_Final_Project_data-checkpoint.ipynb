# %% [markdown]
# <a href="https://colab.research.google.com/github/abagnard/266FinalProject/blob/main/W266_Final_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os, sys, re, csv, json, time, unittest
import itertools, collections
from importlib import reload

import pandas as pd
import numpy as np
from scipy import stats

# Data Scraper Packages
from   bs4    import BeautifulSoup
from   urllib.request import urlopen

# Clean Data Packages
import nltk
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
import glob

# %% [markdown]
# # FOMC Data Loader

# %%
# Pull Dates of FOMC meetings
df_date = pd.read_csv("data/FOMC_data/FOMC_meeting_dates.csv")
meeting_dates = df_date["MeetingDate"].values.tolist()

# %% [markdown]
# ## Create DataFrame with Clean Data
# - Includes press_conference flag that denotes whether a press conference was held for that FOMC meeting

# %%
clean_file_names = glob.glob('data/FOMC_data/FOMC_data_clean/*.txt')

FOMC_records = []
for clean_file_name in clean_file_names:
    meeting_date = clean_file_name.split('/')[-1].split('_')[-1][:-4]
    press_conference = df_date[df_date['MeetingDate'] == int(meeting_date)].iloc[0]['PressConference']
    data = open(clean_file_name).read()
    
    if 'Minutes' in clean_file_name:
        file_type = 'minutes'
        release_date = df_date[df_date['MeetingDate'] == int(meeting_date)].iloc[0]['MinuteNotesReleaseDate']
        # Pull data without stopwords
        file_name = clean_file_name[-24:]
        data_without_stopwords = open('data/FOMC_data/FOMC_data_clean/FOMC_data_clean_without_stopwords/' + file_name).read()
    
    else:
        file_type = 'statement'
        release_date = meeting_date
        # Pull data without stopwords        
        file_name = clean_file_name[-26:]
        data_without_stopwords = open('data/FOMC_data/FOMC_data_clean/FOMC_data_clean_without_stopwords/' + file_name).read()
    
    FOMC_record = {'FOMC_date': meeting_date, 'release_date': release_date, 'document_type': file_type, 'press_conference': press_conference, 'document_data': data, 'document_data_wo_stopwords': data_without_stopwords}
    FOMC_records.append(FOMC_record)


df_FOMC_raw = pd.DataFrame(FOMC_records)

# %%
df_FOMC_raw.FOMC_date = pd.to_datetime(df_FOMC_raw.FOMC_date, format='%Y%m%d')
df_FOMC_raw.release_date = pd.to_datetime(df_FOMC_raw.release_date, format='%Y%m%d')

df_FOMC_raw.head()
# Out:
#    FOMC_date                                      document_data  \
# 0 2006-01-31  minutes of the FOMC january 31 2006 a meeting ...
# 1 2000-10-03  for immediate release the FOMC at its meeting ...
# 2 2000-03-21  for immediate release the FOMC voted today to ...
# 3 2011-01-26  information received since the FOMC met in dec...
# 4 2002-11-06  for immediate release the FOMC decided today t...
#
#                           document_data_wo_stopwords document_type  \
# 0  minutes FOMC january 31 2006 meeting FOMC held...       minutes
# 1  immediate release FOMC meeting today decided m...     statement
# 2  immediate release FOMC voted today raise targe...     statement
# 3  information received since FOMC met december c...     statement
# 4  immediate release FOMC decided today lower tar...     statement
#
#    press_conference release_date
# 0                 0   2006-02-21
# 1                 0   2000-10-03
# 2                 0   2000-03-21
# 3                 0   2011-01-26
# 4                 0   2002-11-06

# %%
df_FOMC_512_raw = df_FOMC_raw

def pull_middle_512_words(data):
    data = data.split(' ')
    midpoint = len(data)//2
    start_idx = midpoint - 200
    end_idx = midpoint + 200
    data_512 = ' '.join(data[start_idx:end_idx])
    return data_512

df_FOMC_512_raw['document_data_512'] = df_FOMC_512_raw['document_data'].apply(lambda data: pull_middle_512_words(data))
df_FOMC_512_raw['document_data_wo_stopwords_512'] = df_FOMC_512_raw['document_data_wo_stopwords'].apply(lambda data: pull_middle_512_words(data))

# %%
df_FOMC_512_raw.head()
# Out:
#    FOMC_date                                      document_data  \
# 0 2006-01-31  minutes of the FOMC january 31 2006 a meeting ...
# 1 2000-10-03  for immediate release the FOMC at its meeting ...
# 2 2000-03-21  for immediate release the FOMC voted today to ...
# 3 2011-01-26  information received since the FOMC met in dec...
# 4 2002-11-06  for immediate release the FOMC decided today t...
#
#                           document_data_wo_stopwords document_type  \
# 0  minutes FOMC january 31 2006 meeting FOMC held...       minutes
# 1  immediate release FOMC meeting today decided m...     statement
# 2  immediate release FOMC voted today raise targe...     statement
# 3  information received since FOMC met december c...     statement
# 4  immediate release FOMC decided today lower tar...     statement
#
#    press_conference release_date  \
# 0                 0   2006-02-21
# 1                 0   2000-10-03
# 2                 0   2000-03-21
# 3                 0   2011-01-26
# 4                 0   2002-11-06
#
#                                    document_data_512  \
# 0  account messrs oliner and slifman associate di...
# 1  utilization of the pool of available workers r...
# 2  growth and of the information currently availa...
# 3                 levels consistent with its mandate
# 4  in productivity is providing important ongoing...
#
#                       document_data_wo_stopwords_512
# 0  messrs moskow poole hoenig alternate members F...
# 1  immediate release FOMC meeting today decided m...
# 2  raise target federal funds rate 25 basis point...
# 3  committee regularly review pace securities pur...
# 4  immediate release FOMC decided today lower tar...

# %% [markdown]
# ### Rename Column Names for 512 subselection

# %%
# df_FOMC_512_raw = df_FOMC_512_raw.drop(['document_data', 'document_data_wo_stopwords'], axis = 1)
# df_FOMC_512_raw = df_FOMC_512_raw.rename(columns = {'document_data_512': 'document_data', 'document_data_wo_stopwords_512': 'document_data_wo_stopwords'})

# %%
# df_FOMC_512_raw.head()

# %% [markdown]
# ## Add Lables to DataFrame
# - Label_Data file includes code on how we caluclate our data lables
#
# #### Create df with labels

# %%
# df_market_data_labels = pd.read_csv('data/Market_data/market_data_labels_by_date.csv', parse_dates=['Date'])
df_market_data_labels = pd.read_csv('data/Market_data/label_data_v2.csv', parse_dates=['Date'])
df_market_data_labels.head()
# Out:
#    Unnamed: 0       Date  Press Release symbol    open    high     low  \
# 0           0 1993-02-03              0  SP500  442.56  447.35  442.56
# 1           1 1993-03-23              0  SP500  448.88  449.80  448.30
# 2           2 1993-05-18              0  SP500  440.39  441.26  437.95
# 3           3 1993-07-07              0  SP500  441.40  443.63  441.40
# 4           4 1993-08-17              0  SP500  452.38  453.70  451.96
#
#     close     volume  day_before_close    ...      prev_fed_rate  \
# 0  447.20  345410000            409.53    ...               3.08
# 1  448.76  232730000            409.91    ...               2.92
# 2  440.32  264300000            412.81    ...               2.94
# 3  442.83  253170000            409.16    ...               3.09
# 4  453.13  261320000            420.74    ...               3.02
#
#    pct_change_in_fed_rate  10_yr  one_day_before_10  two_day_before_10  \
# 0              -15.584416   6.45               7.36               9.01
# 1               -0.342466   5.91               7.62               8.52
# 2               -1.020408   6.15               7.28               8.75
# 3               -9.708738   5.80               6.87               8.02
# 4               -2.649007   5.70               6.56               8.80
#
#    three_day_before_10  prev_days_avg_treas  pct_change_in_treas  \
# 0                 8.21             8.193333           -27.028424
# 1                 9.43             8.523333           -44.218838
# 2                 8.78             8.270000           -34.471545
# 3                 8.95             7.946667           -37.011494
# 4                 8.18             7.846667           -37.660819
#
#    label_market  label_FED
# 0             0         -1
# 1             0         -1
# 2             0         -1
# 3             0         -1
# 4             0         -1
#
# [5 rows x 32 columns]

# %% [markdown]
# #### Update FED and market labels to be positive
# - BERT models will throw errors if labels are negative

# %%
# df_market_data_labels['label_market_raw'] = df_market_data_labels['label_market']
# df_market_data_labels['label_FED_raw'] = df_market_data_labels['label_FED']

# df_market_data_labels['label_market'] = df_market_data_labels['label_market_raw'] + 1
# df_market_data_labels['label_FED'] = df_market_data_labels['label_FED_raw'] + 1

print(df_market_data_labels[['label_market', 'label_FED']].describe())
# Out:
#        label_market   label_FED
# count    442.000000  442.000000
# mean      -0.303167   -0.047511
# std        0.566197    0.796822
# min       -1.000000   -1.000000
# 25%       -1.000000   -1.000000
# 50%        0.000000    0.000000
# 75%        0.000000    1.000000
# max        1.000000    1.000000

# %%
df_FOMC_labeled =  pd.merge(df_FOMC_512_raw, df_market_data_labels, left_on='FOMC_date', right_on='Date')
df_FOMC_labeled.head()
# Out:
#    FOMC_date                                      document_data  \
# 0 2006-01-31  minutes of the FOMC january 31 2006 a meeting ...
# 1 2006-01-31  for immediate release share the FOMC decided t...
# 2 2000-10-03  for immediate release the FOMC at its meeting ...
# 3 2000-10-03  minutes of the FOMC october 3 2000 a meeting o...
# 4 2000-03-21  for immediate release the FOMC voted today to ...
#
#                           document_data_wo_stopwords document_type  \
# 0  minutes FOMC january 31 2006 meeting FOMC held...       minutes
# 1  immediate release share FOMC decided today rai...     statement
# 2  immediate release FOMC meeting today decided m...     statement
# 3  minutes FOMC october 3 2000 meeting FOMC held ...       minutes
# 4  immediate release FOMC voted today raise targe...     statement
#
#    press_conference release_date  \
# 0                 0   2006-02-21
# 1                 0   2006-01-31
# 2                 0   2000-10-03
# 3                 0   2000-11-16
# 4                 0   2000-03-21
#
#                                    document_data_512  \
# 0  account messrs oliner and slifman associate di...
# 1  for immediate release share the FOMC decided t...
# 2  utilization of the pool of available workers r...
# 3  indexes of stock market prices declined somewh...
# 4  growth and of the information currently availa...
#
#                       document_data_wo_stopwords_512  Unnamed: 0       Date  \
# 0  messrs moskow poole hoenig alternate members F...         104 2006-01-31
# 1  immediate release share FOMC decided today rai...         104 2006-01-31
# 2  immediate release FOMC meeting today decided m...          61 2000-10-03
# 3  though previous policy tightening actions yet ...          61 2000-10-03
# 4  raise target federal funds rate 25 basis point...          57 2000-03-21
#
#      ...      prev_fed_rate pct_change_in_fed_rate  10_yr  one_day_before_10  \
# 0    ...               4.47               0.000000   4.53               4.14
# 1    ...               4.47               0.000000   4.53               4.14
# 2    ...               6.51               0.768049   5.87               6.01
# 3    ...               6.51               0.768049   5.87               6.01
# 4    ...               6.02               3.488372   6.13               6.74
#
#    two_day_before_10  three_day_before_10  prev_days_avg_treas  \
# 0               4.00                 5.07             4.403333
# 1               4.00                 5.07             4.403333
# 2               6.61                 6.13             6.250000
# 3               6.61                 6.13             6.250000
# 4               6.28                 7.16             6.726667
#
#    pct_change_in_treas  label_market  label_FED
# 0             2.796174             0          0
# 1             2.796174             0          0
# 2            -6.473595            -1          1
# 3            -6.473595            -1          1
# 4            -9.733551            -1          1
#
# [5 rows x 40 columns]

# %%
# df_FOMC_labeled_small = df_FOMC_labeled[['FOMC_date', 'document_type', 'document_data', 'document_data_wo_stopwords', 'document_data_512', 'document_data_wo_stopwords_512', 'press_conference', 'release_date','label_market', 'label_FED']].copy()

df_FOMC_labeled_small = df_FOMC_labeled[['FOMC_date', 'document_type', 'document_data_512', 'document_data_wo_stopwords_512', 'press_conference', 'release_date','label_market', 'label_FED']].copy()
df_FOMC = df_FOMC_labeled_small
df_FOMC.head()
# Out:
#    FOMC_date document_type                                  document_data_512  \
# 0 2006-01-31       minutes  account messrs oliner and slifman associate di...
# 1 2006-01-31     statement  for immediate release share the FOMC decided t...
# 2 2000-10-03     statement  utilization of the pool of available workers r...
# 3 2000-10-03       minutes  indexes of stock market prices declined somewh...
# 4 2000-03-21     statement  growth and of the information currently availa...
#
#                       document_data_wo_stopwords_512  press_conference  \
# 0  messrs moskow poole hoenig alternate members F...                 0
# 1  immediate release share FOMC decided today rai...                 0
# 2  immediate release FOMC meeting today decided m...                 0
# 3  though previous policy tightening actions yet ...                 0
# 4  raise target federal funds rate 25 basis point...                 0
#
#   release_date  label_market  label_FED
# 0   2006-02-21             0          0
# 1   2006-01-31             0          0
# 2   2000-10-03            -1          1
# 3   2000-11-16            -1          1
# 4   2000-03-21            -1          1

# %% [markdown]
# #### Save FOMC Labeled Data to .csv File

# %%
df_FOMC.to_csv("data/FOMC_labeled_data.csv")
